# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv('C:/Users/jhjjh/Downloads/abalone.csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight', 'Rings']

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
y = df['Rings']
X = df.drop('Rings',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

ly_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ly_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2.195522923484396

# %%
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
df.mode()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0  2.0   0.550      0.45    0.15        0.2225           0.175
# 1  NaN   0.625       NaN     NaN           NaN             NaN
#
#    Viscera weight  Shell weight  Rings
# 0          0.1715         0.275    9.0
# 1             NaN           NaN    NaN

# %%
df=df[df.Height>0]
df.Height.min()
# Out:
# 0.01

# %%
df.groupby('Rings')['Shucked weight'].mean()
# Out:
# Rings
# 1     0.001000
# 2     0.004500
# 3     0.011767
# 4     0.024719
# 5     0.061696
# 6     0.123413
# 7     0.182657
# 8     0.293927
# 9     0.387938
# 10    0.447217
# 11    0.503977
# 12    0.472781
# 13    0.434638
# 14    0.427190
# 15    0.402471
# 16    0.421716
# 17    0.467052
# 18    0.446833
# 19    0.440625
# 20    0.458115
# 21    0.447464
# 22    0.405000
# 23    0.399444
# 24    0.600250
# 25    0.426500
# 26    0.384000
# 27    0.539000
# 29    0.705500
# Name: Shucked weight, dtype: float64

# %%
df.groupby('Rings')['Shucked weight','Whole weight','Shell weight'].mean()
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\2142221974.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Rings')['Shucked weight','Whole weight','Shell weight'].mean()
#        Shucked weight  Whole weight  Shell weight
# Rings
# 1            0.001000      0.002000      0.001500
# 2            0.004500      0.015000      0.005000
# 3            0.011767      0.028400      0.008933
# 4            0.024719      0.059605      0.018000
# 5            0.061696      0.125500      0.036770
# 6            0.123413      0.273713      0.077333
# 7            0.182657      0.397386      0.111648
# 8            0.293927      0.641128      0.178721
# 9            0.387938      0.852013      0.236509
# 10           0.447217      1.008748      0.282976
# 11           0.503977      1.142559      0.319866
# 12           0.472781      1.102904      0.321157
# 13           0.434638      1.075453      0.320828
# 14           0.427190      1.079992      0.329960
# 15           0.402471      1.040951      0.321650
# 16           0.421716      1.133388      0.377858
# 17           0.467052      1.234328      0.393414
# 18           0.446833      1.194333      0.386762
# 19           0.440625      1.166797      0.365312
# 20           0.458115      1.251750      0.425885
# 21           0.447464      1.250607      0.444643
# 22           0.405000      1.221250      0.390000
# 23           0.399444      1.170389      0.370556
# 24           0.600250      1.798750      0.632500
# 25           0.426500      1.406000      0.510000
# 26           0.384000      1.057500      0.375000
# 27           0.539000      1.698000      0.705000
# 29           0.705500      1.807500      0.475000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = 'Sex', data = df, palette="Set3")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'Sex', y = 'Rings', data = df, hue = 'Sex')
sns.violinplot(x = 'Sex', y = 'Rings', data =df)
# Out:
# C:\Users\jhjjh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\jhjjh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 58.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\jhjjh\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 56.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Sex', ylabel='Rings'>

# %%
import numpy as np
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])

# %%
var = 'Shell weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)

# %%
df.drop(df[(df['Shell weight']> 0.6) & (df['Rings'] < 25)].index, inplace=True)
df.drop(df[(df['Shell weight']<0.8) & (df['Rings'] > 25)].index, inplace=True)
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\1903216596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Shell weight']> 0.6) & (df['Rings'] < 25)].index, inplace=True)
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\1903216596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Shell weight']<0.8) & (df['Rings'] > 25)].index, inplace=True)

# %%
var = 'Shell weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)

# %%
df.drop(df[(df['Shell weight']>0.8) & (df['Rings'] > 25)].index, inplace=True)
var = 'Shell weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\4292537532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Shell weight']>0.8) & (df['Rings'] > 25)].index, inplace=True)

# %%
var = 'Viscera weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)

# %%
df.drop(df[(df['Viscera weight']> 0.5) & (df['Rings'] < 20)].index, inplace=True)
df.drop(df[(df['Viscera weight']<0.5) & (df['Rings'] >= 25)].index, inplace=True)
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\3199828771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Viscera weight']> 0.5) & (df['Rings'] < 20)].index, inplace=True)
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\3199828771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Viscera weight']<0.5) & (df['Rings'] >= 25)].index, inplace=True)

# %%
var = 'Viscera weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
var = 'Shucked weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Shucked weight']>= 1) & (df['Rings'] < 20)].index, inplace=True)
df.drop(df[(df['Shucked weight']<1) & (df['Rings'] > 20)].index, inplace=True)
var = 'Shucked weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\4196566613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Shucked weight']>= 1) & (df['Rings'] < 20)].index, inplace=True)
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\4196566613.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Shucked weight']<1) & (df['Rings'] > 20)].index, inplace=True)

# %%
var = 'Whole weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Whole weight']> 2.0) & (df['Rings'] <= 20)].index, inplace=True)
var = 'Whole weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\1067922852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Whole weight']> 2.0) & (df['Rings'] <= 20)].index, inplace=True)

# %%
var = 'Diameter'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Diameter']<=0.1) & (df['Rings']< 2.5)].index, inplace=True)
var = 'Diameter'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\1818504131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Diameter']<=0.1) & (df['Rings']< 2.5)].index, inplace=True)

# %%
var = 'Height'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Height']>0.4) & (df['Rings'] < 15)].index, inplace=True)
var = 'Height'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)
# Out:
# C:\Users\jhjjh\AppData\Local\Temp\ipykernel_24180\470349408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[(df['Height']>0.4) & (df['Rings'] < 15)].index, inplace=True)

# %%
var = 'Length'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
from sklearn.metrics import mean_squared_error

ly_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ly_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2.195522923484396
