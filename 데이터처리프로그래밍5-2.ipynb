# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('C:/Users/jhjjh/Downloads/04_data1.xlsx', index_col='area')
data.head()
# Out:
#               2015_good  2016_good  2017_good  2018_good  2019_good  \
# area
# Nationwide         72.0         54         84        135        117
# Metropolitan       72.0         45         77        126        109
# Seoul              97.0         65        113        140        139
# Busan             102.0         89         86        136        163
# Daegu              90.0        103        111        155        148
#
#               2020_good  2015_common  2016_common  2017_common  2018_common  \
# area
# Nationwide          171        267.0          297          265          209
# Metropolitan        150        259.0          290          260          217
# Seoul               168        243.0          277          230          204
# Busan               208        242.0          259          269          212
# Daegu               176        248.0          246          244          196
#
#               ...  2017_bad  2018_bad  2019_bad  2020_bad  2015_verybad  \
# area          ...
# Nationwide    ...        14        21        16         0           1.0
# Metropolitan  ...        26        22        27         4           4.0
# Seoul         ...        20        21        25         5           4.0
# Busan         ...        10        16         9         2           1.0
# Daegu         ...        10        13        17         4           1.0
#
#               2016_verybad  2017_verybad  2018_verybad  2019_verybad  \
# area
# Nationwide               2             2             0             1
# Metropolitan             2             2             0             3
# Seoul                    1             2             0             3
# Busan                    2             0             1             0
# Daegu                    1             0             1             0
#
#               2020_verybad
# area
# Nationwide               0
# Metropolitan             0
# Seoul                    0
# Busan                    0
# Daegu                    0
#
# [5 rows x 24 columns]

# %%
data2020_good = data['2020_good']
data2019_good = data['2019_good']

# %%
plt.figure(figsize=(20,4))
plt.plot(data2020_good, color='b', marker='o') 
plt.plot(data2019_good, color='r', marker='o')
plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.title('2020 Fine Dust (pm10) Good Line Graph')
plt.legend()
plt.grid() 
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(20,4))

for year in range (2015, 2021):
    year = str(year)+'_good'
    chartdata = data[year]
    plt.plot(chartdata, marker='o', label=year)
plt.xlabel('Area')
plt.ylabel('Micrometer')
plt.title('2015-2020 Fine Dust (pm10) Good Line Graph')
plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib. pyplot as plt

data2015_verybad = data['2015_verybad']
data2020_verybad = data['2020_verybad']

plt.figure(figsize=(20,4))
plt.bar(data2015_verybad. index, data2015_verybad, color= 'g', alpha = 0.5) 
plt.bar(data2020_verybad. index, data2020_verybad, color= 'b') 
plt.xlabel ('Area')
plt.ylabel ('Micrometer')
plt.title('2015 Fine Dust(pm10) Very Bad Bar Graph') 
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
index = np.arange (7)

plt.figure(figsize=(20,4))

data6 = data.loc['Seoul':'Ulsan', '2015_good':'2020_good']
for year in range (2015, 2021):
    year = str(year)+'_good'
    chartdata = data6[year]
    plt.bar(index, chartdata, width=0.15, label=year)
    index = index + 0.15
    
plt.xlabel('Area')
plt.ylabel ('Micrometer')
plt.xticks(index-0.53, ['Seoul', 'Busan', 'Daegu','Incheon',
'Gwangju', 'Daejeon', 'Ulsan'])
plt.title('2015~2020 Fine Dust(pm10) Good Group Bar Graph')
plt.legend()
plt.show()

# %%
data = pd.read_csv('C:/Users/jhjjh/Downloads/04_data2.csv')
data.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
PetalLength = data['PetalLength'] 
PetalWidth = data['PetalWidth']
plt.figure(figsize=(10,4))
plt.scatter(PetalLength, PetalWidth)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Iris Petal Scatter Graph')
plt.grid() 
plt.show()

# %%
PetalLength = data['PetalLength'] 
PetalWidth = data['PetalWidth']

SepalLength = data['SepalLength'] 
SepalWidth = data['SepalWidth']

plt.figure(figsize=(10,4))
plt.scatter(PetalLength, PetalWidth, color='r', edgecolor='w', label='PetalLength PetalWidth')
plt.scatter (SepalLength, SepalWidth, color='b', edgecolor='w',label='SepalLength * SepalWidth')
plt.xlabel('Length')
plt.ylabel('Width')
plt.title('Iris Petal Group Scatter Graph')
plt.legend()
plt.grid()
plt.show()

# %%
setosa_SepalWidth = data.loc[data.Species == 'setosa', ['Species','SepalWidth']]
versicolor_SepalWidth = data.loc[data.Species == 'versicolor', ['Species','SepalWidth']]

plt.figure(figsize=(10,6))
plt.hist(setosa_SepalWidth['SepalWidth'], bins = 5, alpha=0.5,label='setosa', color='red')
plt.hist(versicolor_SepalWidth['SepalWidth'], bins = 5, alpha=0.5,label='versicolor',color='blue')

plt.xlabel('Sepal')
plt.ylabel('Width')
plt.legend()
plt.grid()
plt.show()
